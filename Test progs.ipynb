# %%
import csv
with open(r'C:\Users\015041744\Desktop\EMP.csv') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['AAAA', '5555', 'N', '4']
# ['BBBB', '2222', 'N', '3']
# ['CCCC', '3333', 'Y', '2']
# ['DDDD', '4444', 'N', '1']
# ['EEE', '5555', 'N', '4']
# []
# ['EEEF', '5566', 'N', '5']
# []

# %%
import csv
List = ['EEEF','5566','N','5']
with open(r'C:\Users\015041744\Desktop\EMP.csv','a') as file:
    writer = csv.writer(file)
    writer.writerow(List)

# %%
import matplotlib.pyplot as plt
import numpy as np
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 35, 29, 12, 41]
fig = plt.figure(figsize =(5, 3))
plt.pie(data, labels = cars)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()
